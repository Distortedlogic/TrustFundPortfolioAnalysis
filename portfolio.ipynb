# %%
from purchases import etfs
from portfolio import *

# %%
display_overview(etfs + ["BTC"])
display_portfolio_breakdown()
# Out:
# <style type="text/css">
# #T_a3efb_row0_col2, #T_a3efb_row0_col3, #T_a3efb_row0_col4, #T_a3efb_row0_col6, #T_a3efb_row0_col8, #T_a3efb_row0_col10 {
#   color: red;
# }
# #T_a3efb_row0_col5, #T_a3efb_row0_col7, #T_a3efb_row0_col9, #T_a3efb_row0_col11 {
#   color: green;
# }
# </style>
# <table id="T_a3efb">
#   <thead>
#     <tr>
#       <th id="T_a3efb_level0_col0" class="col_heading level0 col0" >total_cost</th>
#       <th id="T_a3efb_level0_col1" class="col_heading level0 col1" >current_value</th>
#       <th id="T_a3efb_level0_col2" class="col_heading level0 col2" >current_pl</th>
#       <th id="T_a3efb_level0_col3" class="col_heading level0 col3" >roi</th>
#       <th id="T_a3efb_level0_col4" class="col_heading level0 col4" >iwm_roi</th>
#       <th id="T_a3efb_level0_col5" class="col_heading level0 col5" >spy_roi</th>
#       <th id="T_a3efb_level0_col6" class="col_heading level0 col6" >qqq_roi</th>
# ...
