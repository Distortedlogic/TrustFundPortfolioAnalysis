# %%
import pandas as pd
from monte_carlo import *
import json

# %%
current_roi = get_current_roi()
current_roi
# Out:
# -0.0976551256327649

# %%
# sims = run_simulations(1_0)
# sims

# %%
sims = run_simulations_multi(1_000_000)
# Out:
# loaded sims
# 100%|██████████| 1000000/1000000 [11:37<00:00, 1434.70it/s]

# %%
(sims > current_roi).sum()/len(sims)
# Out:
# 0.467479

# %%
sims.describe()
# Out:
# count    1000000.000000
# mean           0.003890
# std            1.353236
# min           -0.687795
# 25%           -0.212288
# 50%           -0.110825
# 75%            0.008767
# max           40.126982
# dtype: float64

# %%
import matplotlib.pyplot as plt
_=plt.hist(sims[sims<2].values, bins=100)
_=plt.axvline(current_roi, color='red', linestyle='dashed', linewidth=1)

# %%
low = 1_0000
high = 1000_000
_=plt.plot(range(high-low),[(sims.iloc[:i] > current_roi).sum()/i for i in range(low,high)])
