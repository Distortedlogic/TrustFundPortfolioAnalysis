# %%
import pandas as pd
from monte_carlo import *
import json

# %%
current_roi = get_current_roi()
current_roi

# %%
sims = run_simulations_multi(1_000_000)
# Out:
# loaded sims
# loaded prices
# 100%|██████████| 1000000/1000000 [10:57<00:00, 1521.01it/s]

# %%
(sims > current_roi).sum()/len(sims)
# Out:
# 0.463968

# %%
sims.describe()
# Out:
# count    1000000.000000
# mean           0.024854
# std            1.664752
# min           -0.713790
# 25%           -0.216215
# 50%           -0.112948
# 75%            0.010919
# max           49.591623
# dtype: float64

# %%
import matplotlib.pyplot as plt
_=plt.hist(sims[sims<2].values, bins=100)
_=plt.axvline(current_roi, color='red', linestyle='dashed', linewidth=1)

# %%
_=plt.plot(range(100000-100),[(sims.iloc[:i] > current_roi).sum()/i for i in range(100,100000)])
